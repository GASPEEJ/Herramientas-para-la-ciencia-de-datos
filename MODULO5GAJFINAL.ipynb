# %% [markdown]
# <a href="https://colab.research.google.com/github/GASPEEJ/Herramientas-para-la-ciencia-de-datos/blob/main/MODULO5GAJFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Peer-graded Assignment: Analyzing Historical
#  Stock/Revenue Data and Building a Dashboard**

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Cierre de acción')
    plt.title(title)
    plt.xlabel('Fecha')
    plt.ylabel('Precio de cierre (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# **Pregunta 1**: Utilice yfinance para extraer datos de stock
#
# Restablezca el índice, guarde y muestre las primeras cinco filas del marco de datos tesla_data mediante la función head. Cargue una captura de pantalla de los resultados y el código desde el comienzo de la pregunta 1 hasta los resultados a continuación.

# %%
tesla_data = yf.download("TSLA", start="2010-01-01", end="2023-12-31")
tesla_data.reset_index(inplace=True)
print("Primeras 5 filas de Tesla Stock Data:")
print(tesla_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Primeras 5 filas de Tesla Stock Data:
# Price                       Date Adj Close     Close      High       Low  \
# Ticker                                TSLA      TSLA      TSLA      TSLA
# 0      2010-06-29 00:00:00+00:00  1.592667  1.592667  1.666667  1.169333
# 1      2010-06-30 00:00:00+00:00  1.588667  1.588667  2.028000  1.553333
# 2      2010-07-01 00:00:00+00:00  1.464000  1.464000  1.728000  1.351333
# 3      2010-07-02 00:00:00+00:00  1.280000  1.280000  1.540000  1.247333
# 4      2010-07-06 00:00:00+00:00  1.074000  1.074000  1.333333  1.055333
#
# Price       Open     Volume
# Ticker      TSLA       TSLA
# 0       1.266667  281494500
# 1       1.719333  257806500
# 2       1.666667  123282000
# 3       1.533333   77097000
# 4       1.333333  103003500

# %% [markdown]
# **Pregunta 2**: Utilice el webscraping para extraer los datos de ingresos de Tesla
#
# Muestre las últimas cinco filas del marco de datos tesla_revenue utilizando la función tail. Sube una captura de pantalla de los resultados.

# %%
tesla_revenue_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
tables = pd.read_html(tesla_revenue_url)
print(f"Se encontraron {len(tables)} tablas.")
for i, table in enumerate(tables):
    print(f"\nTabla {i}:")
    print(table.head())
# Out:
# Se encontraron 6 tablas.
#
# Tabla 0:
#    Tesla Annual Revenue (Millions of US $)  \
# 0                                     2021
# 1                                     2020
# 2                                     2019
# 3                                     2018
# 4                                     2017
#
#   Tesla Annual Revenue (Millions of US $).1
# 0                                   $53,823
# 1                                   $31,536
# 2                                   $24,578
# 3                                   $21,461
# 4                                   $11,759
#
# Tabla 1:
#   Tesla Quarterly Revenue (Millions of US $)  \
# 0                                 2022-09-30
# 1                                 2022-06-30
# 2                                 2022-03-31
# 3                                 2021-12-31
# 4                                 2021-09-30
#
#   Tesla Quarterly Revenue (Millions of US $).1
# 0                                      $21,454
# ...

# %%
tesla_revenue = pd.read_html(tesla_revenue_url)[0]
print("\nÚltimas 5 filas de Tesla Revenue Data:")
print(tesla_revenue.tail())
# Out:
# Últimas 5 filas de Tesla Revenue Data:
#     Tesla Annual Revenue (Millions of US $)  \
# 8                                      2013
# 9                                      2012
# 10                                     2011
# 11                                     2010
# 12                                     2009
#
#    Tesla Annual Revenue (Millions of US $).1
# 8                                     $2,013
# 9                                       $413
# 10                                      $204
# 11                                      $117
# 12                                      $112

# %% [markdown]
# **Pregunta 3:** Use yfinance para extraer datos bursátiles
# Restablezca el índice, guarde y muestre las primeras cinco filas del marco de datos gme_data usando la función head.
# Cargue una captura de pantalla de los resultados y el código desde el comienzo de la pregunta 1 a los resultados a continuación.

# %%
gme_data = yf.download("GME", start="2010-01-01", end="2023-12-31")
gme_data.reset_index(inplace=True)
print("\nPrimeras 5 filas de GameStop Stock Data:")
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Primeras 5 filas de GameStop Stock Data:
# Price                       Date Adj Close   Close    High     Low    Open  \
# Ticker                                 GME     GME     GME     GME     GME
# 0      2010-01-04 00:00:00+00:00  3.854643  5.7250  5.7375  5.5000  5.5175
# 1      2010-01-05 00:00:00+00:00  3.959005  5.8800  5.9350  5.7250  5.7275
# 2      2010-01-06 00:00:00+00:00  4.044851  6.0075  6.0250  5.8050  5.8650
# 3      2010-01-07 00:00:00+00:00  3.443930  5.1150  5.2925  4.8550  5.0025
# 4      2010-01-08 00:00:00+00:00  3.415316  5.0725  5.3075  5.0575  5.1600
#
# Price      Volume
# Ticker        GME
# 0        26702800
# 1        21269600
# 2        21471200
# 3       164761200
# 4        47872400

# %% [markdown]
# **Pregunta 4**: Use Webscraping para extraer datos de ingresos de GME
# Muestre las últimas cinco filas del marco de datos gme_revenue usando la función tail. Cargue una captura de pantalla de los resultados.

# %%
GAME_STOP_URL= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
tables = pd.read_html(GAME_STOP_URL)
print(f"Se encontraron {len(tables)} tablas.")
for i, table in enumerate(tables):
    print(f"\nTabla {i}:")
    print(table.head())
# Out:
# Se encontraron 6 tablas.
#
# Tabla 0:
#    GameStop Annual Revenue (Millions of US $)  \
# 0                                        2020
# 1                                        2019
# 2                                        2018
# 3                                        2017
# 4                                        2016
#
#   GameStop Annual Revenue (Millions of US $).1
# 0                                       $6,466
# 1                                       $8,285
# 2                                       $8,547
# 3                                       $7,965
# 4                                       $9,364
#
# Tabla 1:
#   GameStop Quarterly Revenue (Millions of US $)  \
# 0                                    2020-04-30
# 1                                    2020-01-31
# 2                                    2019-10-31
# 3                                    2019-07-31
# 4                                    2019-04-30
#
#   GameStop Quarterly Revenue (Millions of US $).1
# ...

# %%
gme_revenue = pd.read_html(GAME_STOP_URL)[0]
print("\nÚltimas 5 filas de GameStop Revenue Data:")
print(gme_revenue.tail())
# Out:
# Últimas 5 filas de GameStop Revenue Data:
#     GameStop Annual Revenue (Millions of US $)  \
# 11                                        2009
# 12                                        2008
# 13                                        2007
# 14                                        2006
# 15                                        2005
#
#    GameStop Annual Revenue (Millions of US $).1
# 11                                       $8,806
# 12                                       $7,094
# 13                                       $5,319
# 14                                       $3,092
# 15                                       $1,843

# %% [markdown]
# **Pregunta 5:** Dibuje un gráfico de las acciones de Tesla
# Use la función make_graph para graficar los datos de las acciones de Tesla y proporcione un título para el gráfico.
# Cargue una captura de pantalla de sus resultados.

# %%
make_graph(tesla_data, "Precio de las Acciones de Tesla (2010-2024)")

# %% [markdown]
# **Pregunta 6:** Dibuje un gráfico de las acciones de GameStop
# Use la función make_graph para graficar los datos de las acciones de GameStop y proporcione un título para el gráfico.
# Cargue una captura de pantalla de sus resultados.

# %%
make_graph(gme_data, "Precio de las Acciones de GameStop (2010-2024)")

# %% [markdown]
# Autor :Gabriel Aspee
